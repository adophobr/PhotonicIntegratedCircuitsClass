# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using MPI version 4.0, 1 processes

# %% [markdown]
# O primeiro exemplo é o estudo da propagação do campo eletromagnético em um guia óptico de silício (Si = 3,54) de largura de 1 um. Para tanto, vamos considerar um guia de comprimento de 3 um. A região de simulação será de 5 um em $x$ e 3 um em $y$. Iremos considerar, inicialmente, um simulação 2D. Os passos para definição do ambiente de simulação são:

# %% [markdown]
# 1. Definir a cécula computacional (região de simulação)
# 2. Definir os materiais
# 3. Definir a geometria
# 4. Definir as fontes ópticas
# 5. Definir as condições de contorno
# 6. Definir os monitores de campo
# 7. Criar os objetos de simulação

# %% [markdown]
# ### Parâmetros de simulação

# %% [markdown]
# Inicialmente, precisamos definir as variáveis utilizadas para definir a dimensão e posição do componente.

# %%
sx = 5  # size of cell in X direction
sy = 3  # size of cell in Y direction
sz = 2  # size of cell in Z direction

pad = 0    # padding distance between waveguide and cell edge
w   = 0.5  # Si width (um)
h   = 0.25 # Si height (um)
l   = 5    # Si length (um)

wvg_xcen = 0.5*(sx-l-2*pad)  # x center of horiz. wvg
wvg_ycen = 0  # y center of vert. wvg
wvg_zcen = 0  # y center of vert. wvg

# %% [markdown]
# Precisamos definir a frequência do pulso. A unidade de comprimento neste exemplo é 1 um. A frequência da fonte contínua (ContinuousSource) é 0.15 e, portanto, no vácuo, o comprimento de onda é 1/0.15 = 6.67 um e aproximadamente 2 um (1,9245 um) no material (Si=3,54). Vamos considerar 100 pontos ao longo da banda de simulação.

# %%
fcen = 1/0.15
df = 0.1     
nfreq = 100  # number of frequencies at which to compute flux
#lambda_min = 0.4            # minimum source wavelength
#lambda_max = 0.8            # maximum source wavelength
#fmin = 1/lambda_max         # minimum source frequency
#fmax = 1/lambda_min         # maximum source frequency
#fcen = 0.5*(fmin+fmax)      # source frequency center
#df = fmax-fmin              # source frequency width

# %% [markdown]
# Meep discretiza a estrutura no espaço e tempo, especificada pela variável $resolution$, que descreve o número de pixels por unidade de comprimento. Considerando inicialmente uma resolução de 10 pixels/um, ou 66,7 pixels/comprimento de onda (6.67 um x 10 pixels/um) ou cerca de 20 pixels/um (19,245 pixels/comprimento de onda) no material. Teremos uma 50x30 células ((sx,sy)*resolution).

# %%
resolution = 10

# %% [markdown]
# Para condições de fronteira, utilizaremos fronteiras absorventes ao redor da célula, do tipo PML (*perfectly matched layers*). Definimos uma largura de 1 um para essas fronteiras.

# %%
dpml = .5

# %% [markdown]
# ### Definir a célula computacional (região de simulação)
# Maiores informações https://meep.readthedocs.io/en/latest/Python_User_Interface/#vector3.

# %%
cell = mp.Vector3(sx, sy, sz)

# %% [markdown]
# ### Definir os materiais

# %%
from meep.materials import Si

# %% [markdown]
# ### Definir a geometria

# %%
geometry = [mp.Block(size=mp.Vector3(l,w,h),
                     center=mp.Vector3(wvg_xcen,wvg_ycen,wvg_zcen),
                     material=mp.Medium(index=3.54))]

# %% [markdown]
# ### Definir as fontes ópticas

# %%
sources = [
    mp.EigenModeSource(
    mp.ContinuousSource(fcen,fwidth=df),
    component=mp.Ez,
    center=mp.Vector3(-0.5*sx+dpml,wvg_ycen,0),
    size=mp.Vector3(0,4*w,0))
]
# Out:
# /home/adolfofh/mambaforge/lib/python3.9/site-packages/meep/source.py:582: RuntimeWarning: EigenModeSource component is not ALL_COMPONENTS (the default), which makes it non-unidirectional.
#   warnings.warn(

# %% [markdown]
# ### Definir as condições de contorno

# %%
## To add an absorbing layer of thickness 1 μm around all sides of the cell
pml_layers = [mp.PML(dpml)] ## PML layers on all axis
# pml_layers = [mp.PML(thickness=dpml,direction=mp.X)] ## PML layers on x axis

# %% [markdown]
# ### Criar os objetos de simulação

# %%
sim = mp.Simulation(cell_size=cell,
                    dimensions=3,
                    boundary_layers=pml_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)

# %%
# reflected flux
refl_fr = mp.FluxRegion(center=mp.Vector3(-0.5*sx+dpml+0.5,wvg_ycen,0), size=mp.Vector3(0,2*w,0))
refl = sim.add_flux(fcen, df, nfreq, refl_fr)

# transmitted flux
tran_fr = mp.FluxRegion(center=mp.Vector3(0.5*sx-dpml,wvg_ycen,0), size=mp.Vector3(0,2*w,0))
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

# %%
from meep.visualization import Volume
f,ax = plt.subplots(1,3,dpi=100,figsize=(12,6))
sim.plot2D(
    ax=ax[0],
    output_plane=mp.Volume(center=mp.Vector3(), size=mp.Vector3(0,sy,sz)),
    eps_parameters={"colorbar":True}
    )
sim.plot2D(
    ax=ax[1],
    output_plane=mp.Volume(center=mp.Vector3(), size=mp.Vector3(sx,sy,0)),
    eps_parameters={"colorbar":True}
    )
sim.plot2D(
    ax=ax[2],
    output_plane=mp.Volume(center=mp.Vector3(), size=mp.Vector3(sx,0,sz)),
    eps_parameters={"colorbar":True}
    )
plt.tight_layout()
plt.show()
# Out:
#      block, center = (0,0,0)
#           size (5,0.5,0.25)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.5316,12.5316,12.5316)
#      block, center = (0,0,0)
#           size (5,0.5,0.25)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.5316,12.5316,12.5316)
#      block, center = (0,0,0)
#           size (5,0.5,0.25)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.5316,12.5316,12.5316)
# /home/adolfofh/mambaforge/lib/python3.9/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/adolfofh/mambaforge/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
f = plt.figure(dpi=100)
sim.plot3D()
plt.show()
# Out:
# /home/adolfofh/mambaforge/lib/python3.9/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/adolfofh/mambaforge/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# RFBOutputContext()
#      block, center = (0,0,0)
#           size (5,0.5,0.25)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.5316,12.5316,12.5316)

# %%
import math
cell_size = mp.Vector3(2,5,10)
wvl = 1.05  # wavelength
fcen = 1/wvl

vertices = [mp.Vector3(-1,0),
            mp.Vector3(-0.5,math.sqrt(3)/2),
            mp.Vector3(0.5,math.sqrt(3)/2),
            mp.Vector3(1,0),
            mp.Vector3(0.5,-math.sqrt(3)/2),
            mp.Vector3(-0.5,-math.sqrt(3)/2)]

src_cmpt = mp.Ez
src_pt = mp.Vector3(0,0,-1)
sources = [mp.Source(src=mp.GaussianSource(fcen,fwidth=0.1*fcen),
                     size=mp.Vector3(2,5,0),
                     center=src_pt,
                     component=src_cmpt)]

geometry = [mp.Prism(vertices, height=1.0, material=mp.Medium(index=3.5)),
            mp.Cone(radius=1.0, radius2=0.1, height=2.0, material=mp.air)]

sim = mp.Simulation(resolution=50,
                    cell_size=cell_size,
                    sources=sources,
                    )

sim.plot3D()
plt.show()
# Out:
# RFBOutputContext()

# %%
#pt = mp.Vector3(0.5 * sx - dpml - 0.5, wvg_ycen)
#sim.run(until_after_sources=mp.stop_when_fields_decayed(50,mp.Ez,pt,1e-3))
sim.run(until=200)
# Out:
# FloatProgress(value=18.729999542236328, description='0% done ', max=218.72999954223633, min=18.729999542236328…
# on time step 1873 (time=18.73), 4.1819 s/step
# Meep progress: 0.2500004577636723/218.72999954223633 = 0.1% done in 4.1s, 3593.7s to go
# on time step 1898 (time=18.98), 0.164175 s/step
# Meep progress: 0.49000045776367074/218.72999954223633 = 0.2% done in 8.2s, 3647.2s to go
# on time step 1922 (time=19.22), 0.169838 s/step
# Meep progress: 0.7400004577636707/218.72999954223633 = 0.3% done in 12.3s, 3622.7s to go
# on time step 1947 (time=19.47), 0.164346 s/step
# Meep progress: 0.9800004577636727/218.72999954223633 = 0.4% done in 16.3s, 3624.1s to go
# on time step 1971 (time=19.71), 0.167187 s/step
# Meep progress: 1.2300004577636727/218.72999954223633 = 0.6% done in 20.4s, 3608.9s to go
# on time step 1996 (time=19.96), 0.163914 s/step
# Meep progress: 1.4800004577636727/218.72999954223633 = 0.7% done in 24.5s, 3592.5s to go
# on time step 2021 (time=20.21), 0.162577 s/step
# Meep progress: 1.7300004577636727/218.72999954223633 = 0.8% done in 28.6s, 3583.6s to go
# on time step 2046 (time=20.46), 0.163806 s/step
# Meep progress: 1.9600004577636732/218.72999954223633 = 0.9% done in 32.6s, 3603.9s to go
# on time step 2069 (time=20.69), 0.174607 s/step
# Meep progress: 2.2000004577636716/218.72999954223633 = 1.0% done in 36.7s, 3615.4s to go
# on time step 2093 (time=20.93), 0.172828 s/step
# Meep progress: 2.4500004577636716/218.72999954223633 = 1.1% done in 40.8s, 3602.4s to go
# on time step 2118 (time=21.18), 0.162913 s/step
# Meep progress: 2.7000004577636716/218.72999954223633 = 1.2% done in 44.9s, 3592.8s to go
# on time step 2143 (time=21.43), 0.163817 s/step
# Meep progress: 2.9500004577636716/218.72999954223633 = 1.3% done in 48.9s, 3578.2s to go
# on time step 2168 (time=21.68), 0.160613 s/step
# Meep progress: 3.2000004577636716/218.72999954223633 = 1.5% done in 53.0s, 3572.3s to go
# on time step 2193 (time=21.93), 0.164734 s/step
# Meep progress: 3.4500004577636716/218.72999954223633 = 1.6% done in 57.1s, 3564.9s to go
# on time step 2218 (time=22.18), 0.16367 s/step
# Meep progress: 3.7000004577636716/218.72999954223633 = 1.7% done in 61.1s, 3553.1s to go
# on time step 2243 (time=22.43), 0.160272 s/step
# Meep progress: 3.9500004577636716/218.72999954223633 = 1.8% done in 65.1s, 3542.4s to go
# on time step 2268 (time=22.68), 0.160358 s/step
# Meep progress: 4.200000457763672/218.72999954223633 = 1.9% done in 69.2s, 3532.5s to go
# on time step 2293 (time=22.93), 0.160453 s/step
# Meep progress: 4.450000457763672/218.72999954223633 = 2.0% done in 73.2s, 3522.9s to go
# on time step 2318 (time=23.18), 0.160031 s/step
# Meep progress: 4.700000457763672/218.72999954223633 = 2.1% done in 77.2s, 3514.1s to go
# on time step 2343 (time=23.43), 0.16033 s/step
# Meep progress: 4.950000457763672/218.72999954223633 = 2.3% done in 81.2s, 3506.2s to go
# on time step 2368 (time=23.68), 0.160604 s/step
# Meep progress: 5.200000457763672/218.72999954223633 = 2.4% done in 85.2s, 3498.2s to go
# on time step 2393 (time=23.93), 0.160229 s/step
# Meep progress: 5.450000457763672/218.72999954223633 = 2.5% done in 89.3s, 3493.8s to go
# on time step 2418 (time=24.18), 0.163518 s/step
# Meep progress: 5.700000457763672/218.72999954223633 = 2.6% done in 93.3s, 3488.5s to go
# on time step 2443 (time=24.43), 0.16245 s/step
# Meep progress: 5.950000457763672/218.72999954223633 = 2.7% done in 97.4s, 3484.8s to go
# on time step 2468 (time=24.68), 0.164128 s/step
# Meep progress: 6.200000457763672/218.72999954223633 = 2.8% done in 101.5s, 3479.5s to go
# on time step 2493 (time=24.93), 0.162359 s/step
# Meep progress: 6.450000457763672/218.72999954223633 = 2.9% done in 105.5s, 3472.7s to go
# on time step 2518 (time=25.18), 0.160426 s/step
# Meep progress: 6.700000457763672/218.72999954223633 = 3.1% done in 109.6s, 3467.4s to go
# on time step 2543 (time=25.43), 0.162129 s/step
# Meep progress: 6.950000457763672/218.72999954223633 = 3.2% done in 113.6s, 3461.1s to go
# on time step 2568 (time=25.68), 0.160513 s/step
# Meep progress: 7.210000457763673/218.72999954223633 = 3.3% done in 117.7s, 3454.2s to go
# on time step 2594 (time=25.94), 0.159939 s/step
# Meep progress: 7.460000457763673/218.72999954223633 = 3.4% done in 121.7s, 3447.9s to go
# on time step 2619 (time=26.19), 0.160181 s/step
# Meep progress: 7.710000457763673/218.72999954223633 = 3.5% done in 125.7s, 3441.7s to go
# on time step 2644 (time=26.44), 0.16006 s/step
# Meep progress: 7.960000457763673/218.72999954223633 = 3.6% done in 129.8s, 3436.1s to go
# on time step 2669 (time=26.69), 0.160799 s/step
# Meep progress: 8.210000457763673/218.72999954223633 = 3.8% done in 133.8s, 3430.4s to go
# on time step 2694 (time=26.94), 0.160482 s/step
# Meep progress: 8.460000457763673/218.72999954223633 = 3.9% done in 137.8s, 3425.4s to go
# on time step 2719 (time=27.19), 0.161508 s/step
# Meep progress: 8.710000457763673/218.72999954223633 = 4.0% done in 141.8s, 3419.9s to go
# on time step 2744 (time=27.44), 0.160414 s/step
# Meep progress: 8.960000457763673/218.72999954223633 = 4.1% done in 145.8s, 3414.6s to go
# on time step 2769 (time=27.69), 0.160786 s/step
# Meep progress: 9.220000457763671/218.72999954223633 = 4.2% done in 150.0s, 3408.8s to go
# on time step 2795 (time=27.95), 0.160116 s/step
# Meep progress: 9.470000457763671/218.72999954223633 = 4.3% done in 154.1s, 3404.4s to go
# on time step 2820 (time=28.2), 0.162114 s/step
# Meep progress: 9.720000457763671/218.72999954223633 = 4.4% done in 158.1s, 3400.6s to go
# on time step 2845 (time=28.45), 0.163115 s/step
# Meep progress: 9.970000457763671/218.72999954223633 = 4.6% done in 162.2s, 3396.1s to go
# on time step 2870 (time=28.7), 0.16177 s/step
# Meep progress: 10.220000457763671/218.72999954223633 = 4.7% done in 166.3s, 3391.9s to go
# on time step 2895 (time=28.95), 0.162432 s/step
# Meep progress: 10.470000457763671/218.72999954223633 = 4.8% done in 170.3s, 3388.2s to go
# on time step 2920 (time=29.2), 0.163361 s/step
# Meep progress: 10.720000457763671/218.72999954223633 = 4.9% done in 174.4s, 3384.3s to go
# on time step 2945 (time=29.45), 0.163164 s/step
# Meep progress: 10.970000457763671/218.72999954223633 = 5.0% done in 178.5s, 3380.3s to go
# on time step 2970 (time=29.7), 0.162839 s/step
# Meep progress: 11.210000457763673/218.72999954223633 = 5.1% done in 182.6s, 3380.1s to go
# on time step 2994 (time=29.94), 0.170972 s/step
# Meep progress: 11.450000457763672/218.72999954223633 = 5.2% done in 186.6s, 3378.8s to go
# on time step 3018 (time=30.18), 0.16872 s/step
# Meep progress: 11.690000457763674/218.72999954223633 = 5.3% done in 190.8s, 3378.8s to go
# on time step 3042 (time=30.42), 0.172326 s/step
# Meep progress: 11.940000457763674/218.72999954223633 = 5.5% done in 194.9s, 3375.4s to go
# on time step 3067 (time=30.67), 0.164788 s/step
# Meep progress: 12.170000457763674/218.72999954223633 = 5.6% done in 198.9s, 3376.2s to go
# on time step 3090 (time=30.9), 0.174898 s/step
# Meep progress: 12.410000457763672/218.72999954223633 = 5.7% done in 203.0s, 3374.3s to go
# on time step 3114 (time=31.14), 0.168376 s/step
# Meep progress: 12.660000457763672/218.72999954223633 = 5.8% done in 207.1s, 3370.5s to go
# on time step 3139 (time=31.39), 0.16423 s/step
# Meep progress: 12.910000457763672/218.72999954223633 = 5.9% done in 211.1s, 3365.3s to go
# on time step 3164 (time=31.64), 0.160699 s/step
# Meep progress: 13.160000457763672/218.72999954223633 = 6.0% done in 215.1s, 3360.2s to go
# on time step 3189 (time=31.89), 0.161001 s/step
# Meep progress: 13.410000457763672/218.72999954223633 = 6.1% done in 219.2s, 3355.6s to go
# on time step 3214 (time=32.14), 0.162133 s/step
# Meep progress: 13.660000457763672/218.72999954223633 = 6.2% done in 223.2s, 3350.9s to go
# on time step 3239 (time=32.39), 0.161839 s/step
# Meep progress: 13.910000457763672/218.72999954223633 = 6.4% done in 227.2s, 3346.1s to go
# on time step 3264 (time=32.64), 0.161456 s/step
# Meep progress: 14.160000457763672/218.72999954223633 = 6.5% done in 231.3s, 3340.9s to go
# on time step 3289 (time=32.89), 0.160089 s/step
# Meep progress: 14.410000457763672/218.72999954223633 = 6.6% done in 235.3s, 3336.0s to go
# on time step 3314 (time=33.14), 0.161016 s/step
# Meep progress: 14.660000457763672/218.72999954223633 = 6.7% done in 239.3s, 3331.4s to go
# on time step 3339 (time=33.39), 0.161814 s/step
# Meep progress: 14.910000457763672/218.72999954223633 = 6.8% done in 243.4s, 3326.8s to go
# on time step 3364 (time=33.64), 0.16172 s/step
# Meep progress: 15.160000457763672/218.72999954223633 = 6.9% done in 247.4s, 3322.3s to go
# on time step 3389 (time=33.89), 0.161932 s/step
# Meep progress: 15.410000457763672/218.72999954223633 = 7.0% done in 251.5s, 3318.1s to go
# on time step 3414 (time=34.14), 0.162754 s/step
# Meep progress: 15.660000457763672/218.72999954223633 = 7.2% done in 255.5s, 3313.6s to go
# on time step 3439 (time=34.39), 0.162028 s/step
# Meep progress: 15.910000457763672/218.72999954223633 = 7.3% done in 259.6s, 3308.8s to go
# on time step 3464 (time=34.64), 0.16077 s/step
# Meep progress: 16.160000457763672/218.72999954223633 = 7.4% done in 263.6s, 3304.3s to go
# on time step 3489 (time=34.89), 0.161989 s/step
# Meep progress: 16.400000457763674/218.72999954223633 = 7.5% done in 267.7s, 3302.2s to go
# on time step 3513 (time=35.13), 0.169185 s/step
# Meep progress: 16.60000045776367/218.72999954223633 = 7.6% done in 271.7s, 3308.5s to go
# on time step 3533 (time=35.33), 0.202427 s/step
# Meep progress: 16.750000457763676/218.72999954223633 = 7.7% done in 275.7s, 3325.0s to go
# on time step 3548 (time=35.48), 0.268083 s/step
# Meep progress: 16.95000045776367/218.72999954223633 = 7.7% done in 279.8s, 3330.4s to go
# on time step 3568 (time=35.68), 0.201412 s/step
# Meep progress: 17.17000045776367/218.72999954223633 = 7.8% done in 283.9s, 3332.3s to go
# on time step 3590 (time=35.9), 0.186135 s/step
# Meep progress: 17.400000457763674/218.72999954223633 = 8.0% done in 287.9s, 3330.8s to go
# on time step 3613 (time=36.13), 0.173927 s/step
# Meep progress: 17.650000457763674/218.72999954223633 = 8.1% done in 291.9s, 3325.9s to go
# on time step 3638 (time=36.38), 0.162798 s/step
# Meep progress: 17.900000457763674/218.72999954223633 = 8.2% done in 296.0s, 3321.0s to go
# on time step 3663 (time=36.63), 0.162834 s/step
# Meep progress: 18.150000457763674/218.72999954223633 = 8.3% done in 300.1s, 3316.1s to go
# on time step 3688 (time=36.88), 0.162527 s/step
# Meep progress: 18.400000457763674/218.72999954223633 = 8.4% done in 304.2s, 3312.2s to go
# on time step 3713 (time=37.13), 0.166317 s/step
# Meep progress: 18.64000045776367/218.72999954223633 = 8.5% done in 308.3s, 3309.7s to go
# on time step 3737 (time=37.37), 0.170641 s/step
# Meep progress: 18.88000045776367/218.72999954223633 = 8.6% done in 312.4s, 3307.1s to go
# on time step 3761 (time=37.61), 0.170974 s/step
# Meep progress: 19.070000457763676/218.72999954223633 = 8.7% done in 316.6s, 3314.3s to go
# on time step 3780 (time=37.8), 0.217342 s/step
# Meep progress: 19.230000457763673/218.72999954223633 = 8.8% done in 320.6s, 3325.7s to go
# on time step 3796 (time=37.96), 0.250479 s/step
# Meep progress: 19.470000457763675/218.72999954223633 = 8.9% done in 324.6s, 3322.3s to go
# on time step 3820 (time=38.2), 0.169327 s/step
# Meep progress: 19.71000045776367/218.72999954223633 = 9.0% done in 328.6s, 3318.4s to go
# on time step 3844 (time=38.44), 0.167264 s/step
# Meep progress: 19.95000045776367/218.72999954223633 = 9.1% done in 332.7s, 3315.4s to go
# on time step 3868 (time=38.68), 0.170778 s/step
# Meep progress: 20.20000045776367/218.72999954223633 = 9.2% done in 336.9s, 3310.7s to go
# on time step 3893 (time=38.93), 0.164626 s/step
# Meep progress: 20.45000045776367/218.72999954223633 = 9.3% done in 341.0s, 3306.3s to go
# on time step 3918 (time=39.18), 0.165823 s/step
# Meep progress: 20.70000045776367/218.72999954223633 = 9.5% done in 345.1s, 3301.3s to go
# on time step 3943 (time=39.43), 0.163376 s/step
# Meep progress: 20.95000045776367/218.72999954223633 = 9.6% done in 349.2s, 3296.8s to go
# on time step 3968 (time=39.68), 0.165031 s/step
# Meep progress: 21.190000457763674/218.72999954223633 = 9.7% done in 353.3s, 3293.5s to go
# on time step 3992 (time=39.92), 0.16968 s/step
# Meep progress: 21.440000457763674/218.72999954223633 = 9.8% done in 357.4s, 3288.8s to go
# on time step 4017 (time=40.17), 0.164423 s/step
# Meep progress: 21.680000457763676/218.72999954223633 = 9.9% done in 361.6s, 3286.2s to go
# on time step 4041 (time=40.41), 0.173357 s/step
# Meep progress: 21.870000457763673/218.72999954223633 = 10.0% done in 365.7s, 3291.8s to go
# on time step 4060 (time=40.6), 0.217734 s/step
# Meep progress: 22.110000457763675/218.72999954223633 = 10.1% done in 369.9s, 3289.1s to go
# on time step 4084 (time=40.84), 0.173519 s/step
# Meep progress: 22.340000457763672/218.72999954223633 = 10.2% done in 373.9s, 3287.3s to go
# on time step 4107 (time=41.07), 0.177123 s/step
# Meep progress: 22.580000457763674/218.72999954223633 = 10.3% done in 378.0s, 3284.0s to go
# on time step 4131 (time=41.31), 0.170913 s/step
# Meep progress: 22.830000457763674/218.72999954223633 = 10.4% done in 382.1s, 3278.5s to go
# on time step 4156 (time=41.56), 0.16146 s/step
# Meep progress: 23.080000457763674/218.72999954223633 = 10.6% done in 386.1s, 3273.3s to go
# on time step 4181 (time=41.81), 0.16253 s/step
# Meep progress: 23.330000457763674/218.72999954223633 = 10.7% done in 390.2s, 3268.1s to go
# on time step 4206 (time=42.06), 0.162146 s/step
# Meep progress: 23.570000457763676/218.72999954223633 = 10.8% done in 394.3s, 3264.5s to go
# on time step 4230 (time=42.3), 0.169419 s/step
# Meep progress: 23.820000457763676/218.72999954223633 = 10.9% done in 398.4s, 3260.1s to go
# on time step 4255 (time=42.55), 0.166281 s/step
# Meep progress: 24.070000457763676/218.72999954223633 = 11.0% done in 402.4s, 3254.7s to go
# on time step 4280 (time=42.8), 0.160997 s/step
# Meep progress: 24.320000457763676/218.72999954223633 = 11.1% done in 406.6s, 3250.0s to go
# on time step 4305 (time=43.05), 0.164823 s/step
# Meep progress: 24.570000457763676/218.72999954223633 = 11.2% done in 410.7s, 3245.3s to go
# on time step 4330 (time=43.3), 0.16444 s/step
# Meep progress: 24.790000457763675/218.72999954223633 = 11.3% done in 414.8s, 3245.0s to go
# on time step 4352 (time=43.52), 0.186593 s/step
# Meep progress: 25.000000457763676/218.72999954223633 = 11.4% done in 418.9s, 3246.4s to go
# on time step 4373 (time=43.73), 0.19799 s/step
# Meep progress: 25.21000045776367/218.72999954223633 = 11.5% done in 423.0s, 3247.3s to go
# on time step 4394 (time=43.94), 0.194938 s/step
# Meep progress: 25.440000457763674/218.72999954223633 = 11.6% done in 427.1s, 3245.0s to go
# on time step 4417 (time=44.17), 0.176167 s/step
# Meep progress: 25.67000045776367/218.72999954223633 = 11.7% done in 431.2s, 3243.2s to go
# on time step 4440 (time=44.4), 0.179852 s/step
# Meep progress: 25.900000457763674/218.72999954223633 = 11.8% done in 435.3s, 3240.8s to go
# on time step 4463 (time=44.63), 0.176497 s/step
# Meep progress: 26.13000045776367/218.72999954223633 = 11.9% done in 439.3s, 3238.3s to go
# on time step 4486 (time=44.86), 0.176328 s/step
# Meep progress: 26.35000045776367/218.72999954223633 = 12.0% done in 443.4s, 3237.1s to go
# on time step 4508 (time=45.08), 0.183691 s/step
# Meep progress: 26.580000457763674/218.72999954223633 = 12.2% done in 447.4s, 3234.4s to go
# on time step 4531 (time=45.31), 0.175255 s/step
# Meep progress: 26.81000045776367/218.72999954223633 = 12.3% done in 451.4s, 3231.7s to go
# on time step 4554 (time=45.54), 0.175354 s/step
# Meep progress: 27.040000457763675/218.72999954223633 = 12.4% done in 455.5s, 3229.1s to go
# on time step 4577 (time=45.77), 0.176448 s/step
# Meep progress: 27.260000457763674/218.72999954223633 = 12.5% done in 459.6s, 3228.4s to go
# on time step 4599 (time=45.99), 0.18787 s/step
# Meep progress: 27.470000457763675/218.72999954223633 = 12.6% done in 463.7s, 3228.4s to go
# on time step 4620 (time=46.2), 0.19289 s/step
# Meep progress: 27.690000457763674/218.72999954223633 = 12.7% done in 467.9s, 3227.9s to go
# on time step 4642 (time=46.42), 0.189343 s/step
# Meep progress: 27.92000045776367/218.72999954223633 = 12.8% done in 472.0s, 3225.5s to go
# on time step 4665 (time=46.65), 0.17858 s/step
# Meep progress: 28.17000045776367/218.72999954223633 = 12.9% done in 476.0s, 3220.1s to go
# on time step 4690 (time=46.9), 0.16215 s/step
# Meep progress: 28.42000045776367/218.72999954223633 = 13.0% done in 480.1s, 3215.1s to go
# on time step 4715 (time=47.15), 0.164332 s/step
# Meep progress: 28.67000045776367/218.72999954223633 = 13.1% done in 484.2s, 3209.9s to go
# on time step 4740 (time=47.4), 0.162821 s/step
# Meep progress: 28.900000457763674/218.72999954223633 = 13.2% done in 488.3s, 3207.3s to go
# on time step 4763 (time=47.63), 0.177887 s/step
# Meep progress: 29.150000457763674/218.72999954223633 = 13.3% done in 492.4s, 3202.1s to go
# on time step 4788 (time=47.88), 0.162614 s/step
# Meep progress: 29.400000457763674/218.72999954223633 = 13.4% done in 496.4s, 3196.9s to go
# on time step 4813 (time=48.13), 0.162878 s/step
# Meep progress: 29.650000457763674/218.72999954223633 = 13.6% done in 500.5s, 3192.0s to go
# on time step 4838 (time=48.38), 0.164664 s/step
# Meep progress: 29.900000457763674/218.72999954223633 = 13.7% done in 504.6s, 3186.9s to go
# on time step 4863 (time=48.63), 0.163138 s/step
# Meep progress: 30.150000457763674/218.72999954223633 = 13.8% done in 508.6s, 3181.4s to go
# on time step 4888 (time=48.88), 0.160782 s/step
# Meep progress: 30.400000457763674/218.72999954223633 = 13.9% done in 512.7s, 3176.2s to go
# on time step 4913 (time=49.13), 0.161984 s/step
# Meep progress: 30.650000457763674/218.72999954223633 = 14.0% done in 516.7s, 3170.7s to go
# on time step 4938 (time=49.38), 0.160461 s/step
# Meep progress: 30.900000457763674/218.72999954223633 = 14.1% done in 520.8s, 3165.7s to go
# on time step 4963 (time=49.63), 0.163566 s/step
# Meep progress: 31.140000457763676/218.72999954223633 = 14.2% done in 524.8s, 3161.5s to go
# on time step 4987 (time=49.87), 0.167358 s/step
# Meep progress: 31.370000457763673/218.72999954223633 = 14.3% done in 528.8s, 3158.4s to go
# on time step 5010 (time=50.1), 0.173918 s/step
# Meep progress: 31.620000457763673/218.72999954223633 = 14.5% done in 532.9s, 3153.2s to go
# on time step 5035 (time=50.35), 0.162148 s/step
# Meep progress: 31.870000457763673/218.72999954223633 = 14.6% done in 536.9s, 3148.1s to go
# on time step 5060 (time=50.6), 0.16216 s/step
# Meep progress: 32.12000045776367/218.72999954223633 = 14.7% done in 541.0s, 3143.0s to go
# on time step 5085 (time=50.85), 0.162286 s/step
# Meep progress: 32.37000045776367/218.72999954223633 = 14.8% done in 545.0s, 3137.9s to go
# on time step 5110 (time=51.1), 0.162353 s/step
# Meep progress: 32.62000045776367/218.72999954223633 = 14.9% done in 549.1s, 3132.8s to go
# on time step 5135 (time=51.35), 0.162304 s/step
# Meep progress: 32.87000045776367/218.72999954223633 = 15.0% done in 553.2s, 3127.8s to go
# on time step 5160 (time=51.6), 0.162522 s/step
# Meep progress: 33.12000045776367/218.72999954223633 = 15.1% done in 557.2s, 3122.8s to go
# on time step 5185 (time=51.85), 0.162824 s/step
# Meep progress: 33.37000045776367/218.72999954223633 = 15.3% done in 561.3s, 3118.0s to go
# on time step 5210 (time=52.1), 0.163502 s/step
# Meep progress: 33.62000045776367/218.72999954223633 = 15.4% done in 565.4s, 3113.1s to go
# on time step 5235 (time=52.35), 0.163376 s/step
# Meep progress: 33.87000045776367/218.72999954223633 = 15.5% done in 569.5s, 3108.3s to go
# on time step 5260 (time=52.6), 0.163787 s/step
# Meep progress: 34.12000045776367/218.72999954223633 = 15.6% done in 573.6s, 3103.6s to go
# on time step 5285 (time=52.85), 0.1644 s/step
# Meep progress: 34.360000457763675/218.72999954223633 = 15.7% done in 577.7s, 3100.0s to go
# on time step 5309 (time=53.09), 0.171514 s/step
# Meep progress: 34.60000045776367/218.72999954223633 = 15.8% done in 581.8s, 3096.2s to go
# on time step 5333 (time=53.33), 0.170183 s/step
# Meep progress: 34.84000045776367/218.72999954223633 = 15.9% done in 585.9s, 3092.2s to go
# on time step 5357 (time=53.57), 0.168442 s/step
# Meep progress: 35.09000045776367/218.72999954223633 = 16.0% done in 589.9s, 3087.4s to go
# on time step 5382 (time=53.82), 0.163252 s/step
# Meep progress: 35.34000045776367/218.72999954223633 = 16.2% done in 594.1s, 3082.9s to go
# on time step 5407 (time=54.07), 0.165761 s/step
# Meep progress: 35.59000045776367/218.72999954223633 = 16.3% done in 598.2s, 3078.1s to go
# on time step 5432 (time=54.32), 0.163722 s/step
# Meep progress: 35.830000457763674/218.72999954223633 = 16.4% done in 602.2s, 3074.2s to go
# on time step 5456 (time=54.56), 0.169467 s/step
# Meep progress: 36.070000457763676/218.72999954223633 = 16.5% done in 606.3s, 3070.6s to go
# on time step 5480 (time=54.8), 0.170963 s/step
# Meep progress: 36.320000457763676/218.72999954223633 = 16.6% done in 610.5s, 3066.2s to go
# on time step 5505 (time=55.05), 0.166477 s/step
# Meep progress: 36.56000045776367/218.72999954223633 = 16.7% done in 614.6s, 3062.3s to go
# on time step 5529 (time=55.29), 0.16981 s/step
# Meep progress: 36.80000045776367/218.72999954223633 = 16.8% done in 618.6s, 3058.3s to go
# on time step 5553 (time=55.53), 0.16805 s/step
# Meep progress: 37.03000045776367/218.72999954223633 = 16.9% done in 622.7s, 3055.6s to go
# on time step 5576 (time=55.76), 0.178322 s/step
# Meep progress: 37.28000045776367/218.72999954223633 = 17.0% done in 626.9s, 3051.1s to go
# on time step 5601 (time=56.01), 0.165943 s/step
# Meep progress: 37.53000045776367/218.72999954223633 = 17.2% done in 631.0s, 3046.3s to go
# on time step 5626 (time=56.26), 0.163533 s/step
# Meep progress: 37.77000045776367/218.72999954223633 = 17.3% done in 635.0s, 3042.6s to go
# on time step 5650 (time=56.5), 0.170296 s/step
# Meep progress: 38.010000457763674/218.72999954223633 = 17.4% done in 639.1s, 3038.8s to go
# on time step 5674 (time=56.74), 0.170275 s/step
# Meep progress: 38.250000457763676/218.72999954223633 = 17.5% done in 643.2s, 3035.1s to go
# on time step 5698 (time=56.98), 0.171339 s/step
# Meep progress: 38.500000457763676/218.72999954223633 = 17.6% done in 647.4s, 3030.5s to go
# on time step 5723 (time=57.23), 0.164566 s/step
# Meep progress: 38.750000457763676/218.72999954223633 = 17.7% done in 651.5s, 3025.9s to go
# on time step 5748 (time=57.48), 0.165004 s/step
# Meep progress: 39.000000457763676/218.72999954223633 = 17.8% done in 655.6s, 3021.1s to go
# on time step 5773 (time=57.73), 0.162912 s/step
# Meep progress: 39.24000045776367/218.72999954223633 = 17.9% done in 659.7s, 3017.5s to go
# on time step 5797 (time=57.97), 0.171794 s/step
# Meep progress: 39.48000045776367/218.72999954223633 = 18.0% done in 663.7s, 3013.6s to go
# on time step 5821 (time=58.21), 0.169138 s/step
# Meep progress: 39.720000457763675/218.72999954223633 = 18.2% done in 667.8s, 3009.4s to go
# on time step 5845 (time=58.45), 0.167197 s/step
# Meep progress: 39.970000457763675/218.72999954223633 = 18.3% done in 671.8s, 3004.7s to go
# on time step 5870 (time=58.7), 0.163477 s/step
# Meep progress: 40.21000045776367/218.72999954223633 = 18.4% done in 676.0s, 3001.0s to go
# on time step 5894 (time=58.94), 0.17128 s/step
# Meep progress: 40.46000045776367/218.72999954223633 = 18.5% done in 680.0s, 2996.3s to go
# on time step 5919 (time=59.19), 0.163252 s/step
# Meep progress: 40.71000045776367/218.72999954223633 = 18.6% done in 684.1s, 2991.6s to go
# on time step 5944 (time=59.44), 0.163203 s/step
# Meep progress: 40.96000045776367/218.72999954223633 = 18.7% done in 688.2s, 2986.8s to go
# on time step 5969 (time=59.69), 0.163031 s/step
# Meep progress: 41.21000045776367/218.72999954223633 = 18.8% done in 692.3s, 2982.3s to go
# on time step 5994 (time=59.94), 0.165348 s/step
# Meep progress: 41.46000045776367/218.72999954223633 = 19.0% done in 696.5s, 2977.9s to go
# on time step 6019 (time=60.19), 0.166024 s/step
# Meep progress: 41.71000045776367/218.72999954223633 = 19.1% done in 700.6s, 2973.4s to go
# on time step 6044 (time=60.44), 0.165204 s/step
# Meep progress: 41.95000045776367/218.72999954223633 = 19.2% done in 704.6s, 2969.3s to go
# on time step 6068 (time=60.68), 0.167213 s/step
# Meep progress: 42.190000457763674/218.72999954223633 = 19.3% done in 708.7s, 2965.6s to go
# on time step 6092 (time=60.92), 0.171041 s/step
# Meep progress: 42.440000457763674/218.72999954223633 = 19.4% done in 712.8s, 2961.0s to go
# on time step 6117 (time=61.17), 0.164404 s/step
# Meep progress: 42.690000457763674/218.72999954223633 = 19.5% done in 717.0s, 2956.6s to go
# on time step 6142 (time=61.42), 0.165549 s/step
# Meep progress: 42.930000457763676/218.72999954223633 = 19.6% done in 721.1s, 2952.9s to go
# on time step 6166 (time=61.66), 0.171479 s/step
# Meep progress: 43.180000457763676/218.72999954223633 = 19.7% done in 725.2s, 2948.2s to go
# on time step 6191 (time=61.91), 0.163295 s/step
# Meep progress: 43.430000457763676/218.72999954223633 = 19.9% done in 729.3s, 2943.5s to go
# on time step 6216 (time=62.16), 0.16299 s/step
# Meep progress: 43.680000457763676/218.72999954223633 = 20.0% done in 733.3s, 2938.7s to go
# on time step 6241 (time=62.41), 0.161814 s/step
# Meep progress: 43.930000457763676/218.72999954223633 = 20.1% done in 737.3s, 2934.0s to go
# on time step 6266 (time=62.66), 0.16211 s/step
# Meep progress: 44.180000457763676/218.72999954223633 = 20.2% done in 741.4s, 2929.3s to go
# on time step 6291 (time=62.91), 0.163002 s/step
# Meep progress: 44.430000457763676/218.72999954223633 = 20.3% done in 745.5s, 2924.6s to go
# on time step 6316 (time=63.16), 0.162461 s/step
# Meep progress: 44.680000457763676/218.72999954223633 = 20.4% done in 749.5s, 2919.6s to go
# on time step 6341 (time=63.41), 0.160115 s/step
# Meep progress: 44.930000457763676/218.72999954223633 = 20.5% done in 753.6s, 2915.0s to go
# on time step 6366 (time=63.66), 0.162831 s/step
# Meep progress: 45.180000457763676/218.72999954223633 = 20.7% done in 757.6s, 2910.3s to go
# on time step 6391 (time=63.91), 0.163286 s/step
# Meep progress: 45.43000045776367/218.72999954223633 = 20.8% done in 761.7s, 2905.5s to go
# on time step 6416 (time=64.16), 0.160946 s/step
# Meep progress: 45.68000045776367/218.72999954223633 = 20.9% done in 765.7s, 2900.7s to go
# on time step 6441 (time=64.41), 0.161137 s/step
# Meep progress: 45.93000045776367/218.72999954223633 = 21.0% done in 769.7s, 2895.9s to go
# on time step 6466 (time=64.66), 0.161357 s/step
# Meep progress: 46.18000045776367/218.72999954223633 = 21.1% done in 773.8s, 2891.2s to go
# on time step 6491 (time=64.91), 0.162321 s/step
# Meep progress: 46.43000045776367/218.72999954223633 = 21.2% done in 777.8s, 2886.5s to go
# on time step 6516 (time=65.16), 0.161047 s/step
# Meep progress: 46.68000045776367/218.72999954223633 = 21.3% done in 781.9s, 2881.7s to go
# on time step 6541 (time=65.41), 0.161403 s/step
# Meep progress: 46.93000045776367/218.72999954223633 = 21.5% done in 785.9s, 2876.9s to go
# on time step 6566 (time=65.66), 0.160467 s/step
# Meep progress: 47.190000457763674/218.72999954223633 = 21.6% done in 790.0s, 2871.8s to go
# on time step 6592 (time=65.92), 0.159622 s/step
# Meep progress: 47.440000457763674/218.72999954223633 = 21.7% done in 794.0s, 2867.0s to go
# on time step 6617 (time=66.17), 0.160841 s/step
# Meep progress: 47.690000457763674/218.72999954223633 = 21.8% done in 798.1s, 2862.3s to go
# on time step 6642 (time=66.42), 0.161148 s/step
# Meep progress: 47.940000457763674/218.72999954223633 = 21.9% done in 802.1s, 2857.6s to go
# on time step 6667 (time=66.67), 0.162113 s/step
# Meep progress: 48.190000457763674/218.72999954223633 = 22.0% done in 806.1s, 2852.8s to go
# on time step 6692 (time=66.92), 0.160049 s/step
# Meep progress: 48.440000457763674/218.72999954223633 = 22.1% done in 810.2s, 2848.2s to go
# on time step 6717 (time=67.17), 0.162055 s/step
# Meep progress: 48.690000457763674/218.72999954223633 = 22.3% done in 814.2s, 2843.4s to go
# on time step 6742 (time=67.42), 0.16059 s/step
# Meep progress: 48.940000457763674/218.72999954223633 = 22.4% done in 818.2s, 2838.7s to go
# on time step 6767 (time=67.67), 0.161846 s/step
# Meep progress: 49.190000457763674/218.72999954223633 = 22.5% done in 822.3s, 2834.1s to go
# on time step 6792 (time=67.92), 0.162346 s/step
# Meep progress: 49.440000457763674/218.72999954223633 = 22.6% done in 826.4s, 2829.8s to go
# on time step 6817 (time=68.17), 0.165241 s/step
# Meep progress: 49.690000457763674/218.72999954223633 = 22.7% done in 830.5s, 2825.2s to go
# on time step 6842 (time=68.42), 0.161552 s/step
# Meep progress: 49.940000457763674/218.72999954223633 = 22.8% done in 834.5s, 2820.5s to go
# on time step 6867 (time=68.67), 0.161906 s/step
# Meep progress: 50.190000457763674/218.72999954223633 = 22.9% done in 838.6s, 2816.2s to go
# on time step 6892 (time=68.92), 0.164627 s/step
# Meep progress: 50.440000457763674/218.72999954223633 = 23.1% done in 842.7s, 2811.5s to go
# on time step 6917 (time=69.17), 0.161942 s/step
# Meep progress: 50.690000457763674/218.72999954223633 = 23.2% done in 846.7s, 2806.9s to go
# on time step 6942 (time=69.42), 0.161568 s/step
# Meep progress: 50.940000457763674/218.72999954223633 = 23.3% done in 850.8s, 2802.4s to go
# on time step 6967 (time=69.67), 0.162966 s/step
# Meep progress: 51.190000457763674/218.72999954223633 = 23.4% done in 854.8s, 2797.8s to go
# on time step 6992 (time=69.92), 0.161898 s/step
# Meep progress: 51.440000457763674/218.72999954223633 = 23.5% done in 858.9s, 2793.2s to go
# on time step 7017 (time=70.17), 0.16169 s/step
# Meep progress: 51.690000457763674/218.72999954223633 = 23.6% done in 862.9s, 2788.6s to go
# on time step 7042 (time=70.42), 0.161103 s/step
# Meep progress: 51.940000457763674/218.72999954223633 = 23.7% done in 867.0s, 2784.0s to go
# on time step 7067 (time=70.67), 0.162016 s/step
# Meep progress: 52.18000045776367/218.72999954223633 = 23.9% done in 871.0s, 2780.2s to go
# on time step 7091 (time=70.91), 0.169879 s/step
# Meep progress: 52.43000045776367/218.72999954223633 = 24.0% done in 875.1s, 2775.8s to go
# on time step 7116 (time=71.16), 0.163335 s/step
# Meep progress: 52.67000045776368/218.72999954223633 = 24.1% done in 879.2s, 2771.9s to go
# on time step 7140 (time=71.4), 0.168837 s/step
# Meep progress: 52.90000045776367/218.72999954223633 = 24.2% done in 883.2s, 2768.7s to go
# on time step 7163 (time=71.63), 0.175736 s/step
# Meep progress: 53.140000457763676/218.72999954223633 = 24.3% done in 887.3s, 2765.0s to go
# on time step 7187 (time=71.87), 0.170477 s/step
# Meep progress: 53.390000457763676/218.72999954223633 = 24.4% done in 891.5s, 2760.7s to go
# on time step 7212 (time=72.12), 0.16621 s/step
# Meep progress: 53.640000457763676/218.72999954223633 = 24.5% done in 895.5s, 2756.1s to go
# on time step 7237 (time=72.37), 0.161003 s/step
# Meep progress: 53.890000457763676/218.72999954223633 = 24.6% done in 899.5s, 2751.6s to go
# on time step 7262 (time=72.62), 0.162114 s/step
# Meep progress: 54.140000457763676/218.72999954223633 = 24.8% done in 903.6s, 2747.0s to go
# on time step 7287 (time=72.87), 0.161661 s/step
# Meep progress: 54.390000457763676/218.72999954223633 = 24.9% done in 907.6s, 2742.3s to go
# on time step 7312 (time=73.12), 0.160543 s/step
# Meep progress: 54.640000457763676/218.72999954223633 = 25.0% done in 911.6s, 2737.7s to go
# on time step 7337 (time=73.37), 0.160594 s/step
# Meep progress: 54.890000457763676/218.72999954223633 = 25.1% done in 915.8s, 2733.6s to go
# on time step 7362 (time=73.62), 0.167421 s/step
# Meep progress: 55.140000457763676/218.72999954223633 = 25.2% done in 919.9s, 2729.3s to go
# on time step 7387 (time=73.87), 0.164965 s/step
# Meep progress: 55.38000045776367/218.72999954223633 = 25.3% done in 924.0s, 2725.4s to go
# on time step 7411 (time=74.11), 0.168858 s/step
# Meep progress: 55.63000045776367/218.72999954223633 = 25.4% done in 928.1s, 2721.0s to go
# on time step 7436 (time=74.36), 0.164079 s/step
# Meep progress: 55.87000045776368/218.72999954223633 = 25.5% done in 932.3s, 2717.5s to go
# on time step 7460 (time=74.6), 0.173801 s/step
# Meep progress: 56.12000045776368/218.72999954223633 = 25.7% done in 936.4s, 2713.3s to go
# on time step 7485 (time=74.85), 0.166076 s/step
# Meep progress: 56.37000045776368/218.72999954223633 = 25.8% done in 940.6s, 2709.1s to go
# on time step 7510 (time=75.1), 0.167182 s/step
# Meep progress: 56.57000045776367/218.72999954223633 = 25.9% done in 944.7s, 2708.0s to go
# on time step 7530 (time=75.3), 0.205927 s/step
# Meep progress: 56.82000045776367/218.72999954223633 = 26.0% done in 948.9s, 2703.8s to go
# on time step 7555 (time=75.55), 0.16585 s/step
# Meep progress: 57.07000045776367/218.72999954223633 = 26.1% done in 953.0s, 2699.4s to go
# on time step 7580 (time=75.8), 0.164716 s/step
# Meep progress: 57.32000045776367/218.72999954223633 = 26.2% done in 957.0s, 2694.9s to go
# on time step 7605 (time=76.05), 0.161179 s/step
# Meep progress: 57.57000045776367/218.72999954223633 = 26.3% done in 961.0s, 2690.3s to go
# on time step 7630 (time=76.3), 0.161533 s/step
# Meep progress: 57.82000045776367/218.72999954223633 = 26.4% done in 965.1s, 2685.8s to go
# on time step 7655 (time=76.55), 0.162054 s/step
# Meep progress: 58.07000045776367/218.72999954223633 = 26.5% done in 969.2s, 2681.4s to go
# on time step 7680 (time=76.8), 0.163524 s/step
# Meep progress: 58.32000045776367/218.72999954223633 = 26.7% done in 973.3s, 2677.1s to go
# on time step 7705 (time=77.05), 0.16523 s/step
# Meep progress: 58.57000045776367/218.72999954223633 = 26.8% done in 977.4s, 2672.7s to go
# on time step 7730 (time=77.3), 0.16412 s/step
# Meep progress: 58.82000045776367/218.72999954223633 = 26.9% done in 981.5s, 2668.3s to go
# on time step 7755 (time=77.55), 0.162318 s/step
# Meep progress: 59.07000045776367/218.72999954223633 = 27.0% done in 985.5s, 2663.8s to go
# on time step 7780 (time=77.8), 0.162239 s/step
# Meep progress: 59.32000045776367/218.72999954223633 = 27.1% done in 989.6s, 2659.4s to go
# on time step 7805 (time=78.05), 0.163891 s/step
# Meep progress: 59.57000045776367/218.72999954223633 = 27.2% done in 993.7s, 2655.0s to go
# on time step 7830 (time=78.3), 0.162787 s/step
# Meep progress: 59.82000045776367/218.72999954223633 = 27.3% done in 997.8s, 2650.6s to go
# on time step 7855 (time=78.55), 0.164336 s/step
# Meep progress: 60.07000045776367/218.72999954223633 = 27.5% done in 1001.9s, 2646.2s to go
# on time step 7880 (time=78.8), 0.16334 s/step
# Meep progress: 60.32000045776367/218.72999954223633 = 27.6% done in 1005.9s, 2641.8s to go
# on time step 7905 (time=79.05), 0.162346 s/step
# Meep progress: 60.57000045776367/218.72999954223633 = 27.7% done in 1010.0s, 2637.3s to go
# on time step 7930 (time=79.3), 0.161726 s/step
# Meep progress: 60.82000045776367/218.72999954223633 = 27.8% done in 1014.1s, 2632.9s to go
# on time step 7955 (time=79.55), 0.162739 s/step
# Meep progress: 61.07000045776367/218.72999954223633 = 27.9% done in 1018.1s, 2628.5s to go
# on time step 7980 (time=79.8), 0.163342 s/step
# Meep progress: 61.32000045776367/218.72999954223633 = 28.0% done in 1022.2s, 2624.1s to go
# on time step 8005 (time=80.05), 0.163071 s/step
# Meep progress: 61.57000045776367/218.72999954223633 = 28.1% done in 1026.3s, 2619.7s to go
# on time step 8030 (time=80.3), 0.162955 s/step
# Meep progress: 61.82000045776367/218.72999954223633 = 28.3% done in 1030.4s, 2615.3s to go
# on time step 8055 (time=80.55), 0.162751 s/step
# Meep progress: 62.07000045776367/218.72999954223633 = 28.4% done in 1034.4s, 2610.8s to go
# on time step 8080 (time=80.8), 0.162628 s/step
# Meep progress: 62.32000045776367/218.72999954223633 = 28.5% done in 1038.5s, 2606.4s to go
# on time step 8105 (time=81.05), 0.162452 s/step
# Meep progress: 62.57000045776367/218.72999954223633 = 28.6% done in 1042.6s, 2602.1s to go
# on time step 8130 (time=81.3), 0.163955 s/step
# Meep progress: 62.82000045776367/218.72999954223633 = 28.7% done in 1046.7s, 2597.6s to go
# on time step 8155 (time=81.55), 0.162311 s/step
# Meep progress: 63.07000045776367/218.72999954223633 = 28.8% done in 1050.7s, 2593.1s to go
# on time step 8180 (time=81.8), 0.161219 s/step
# Meep progress: 63.32000045776367/218.72999954223633 = 28.9% done in 1054.7s, 2588.6s to go
# on time step 8205 (time=82.05), 0.161274 s/step
# Meep progress: 63.57000045776367/218.72999954223633 = 29.1% done in 1058.8s, 2584.2s to go
# on time step 8230 (time=82.3), 0.162391 s/step
# Meep progress: 63.82000045776367/218.72999954223633 = 29.2% done in 1062.8s, 2579.8s to go
# on time step 8255 (time=82.55), 0.161392 s/step
# Meep progress: 64.07000045776367/218.72999954223633 = 29.3% done in 1066.9s, 2575.3s to go
# on time step 8280 (time=82.8), 0.161863 s/step
# Meep progress: 64.32000045776367/218.72999954223633 = 29.4% done in 1070.9s, 2570.9s to go
# on time step 8305 (time=83.05), 0.161631 s/step
# Meep progress: 64.57000045776367/218.72999954223633 = 29.5% done in 1074.9s, 2566.4s to go
# on time step 8330 (time=83.3), 0.161657 s/step
# Meep progress: 64.82000045776367/218.72999954223633 = 29.6% done in 1079.0s, 2562.0s to go
# on time step 8355 (time=83.55), 0.161507 s/step
# Meep progress: 65.07000045776367/218.72999954223633 = 29.7% done in 1083.0s, 2557.6s to go
# on time step 8380 (time=83.8), 0.16273 s/step
# Meep progress: 65.32000045776367/218.72999954223633 = 29.9% done in 1087.1s, 2553.2s to go
# on time step 8405 (time=84.05), 0.163024 s/step
# Meep progress: 65.57000045776367/218.72999954223633 = 30.0% done in 1091.1s, 2548.7s to go
# on time step 8430 (time=84.3), 0.160616 s/step
# Meep progress: 65.82000045776367/218.72999954223633 = 30.1% done in 1095.2s, 2544.3s to go
# on time step 8455 (time=84.55), 0.161476 s/step
# Meep progress: 66.07000045776367/218.72999954223633 = 30.2% done in 1099.2s, 2539.8s to go
# on time step 8480 (time=84.8), 0.161797 s/step
# Meep progress: 66.32000045776367/218.72999954223633 = 30.3% done in 1103.3s, 2535.4s to go
# on time step 8505 (time=85.05), 0.161682 s/step
# Meep progress: 66.57000045776367/218.72999954223633 = 30.4% done in 1107.3s, 2531.0s to go
# on time step 8530 (time=85.3), 0.162235 s/step
# Meep progress: 66.82000045776367/218.72999954223633 = 30.5% done in 1111.4s, 2526.6s to go
# on time step 8555 (time=85.55), 0.161865 s/step
# Meep progress: 67.07000045776367/218.72999954223633 = 30.7% done in 1115.4s, 2522.3s to go
# on time step 8580 (time=85.8), 0.16322 s/step
# Meep progress: 67.32000045776367/218.72999954223633 = 30.8% done in 1119.5s, 2517.9s to go
# on time step 8605 (time=86.05), 0.162958 s/step
# Meep progress: 67.57000045776367/218.72999954223633 = 30.9% done in 1123.6s, 2513.7s to go
# on time step 8630 (time=86.3), 0.164066 s/step
# Meep progress: 67.82000045776367/218.72999954223633 = 31.0% done in 1127.8s, 2509.5s to go
# on time step 8655 (time=86.55), 0.166256 s/step
# Meep progress: 68.07000045776367/218.72999954223633 = 31.1% done in 1131.9s, 2505.2s to go
# on time step 8680 (time=86.8), 0.163407 s/step
# Meep progress: 68.32000045776367/218.72999954223633 = 31.2% done in 1135.9s, 2500.8s to go
# on time step 8705 (time=87.05), 0.162922 s/step
# Meep progress: 68.57000045776367/218.72999954223633 = 31.3% done in 1140.1s, 2496.6s to go
# on time step 8730 (time=87.3), 0.165041 s/step
# Meep progress: 68.81000045776368/218.72999954223633 = 31.5% done in 1144.1s, 2492.7s to go
# on time step 8754 (time=87.54), 0.167011 s/step
# Meep progress: 69.06000045776368/218.72999954223633 = 31.6% done in 1148.2s, 2488.4s to go
# on time step 8779 (time=87.79), 0.164958 s/step
# Meep progress: 69.31000045776368/218.72999954223633 = 31.7% done in 1152.3s, 2484.1s to go
# on time step 8804 (time=88.04), 0.163102 s/step
# Meep progress: 69.56000045776368/218.72999954223633 = 31.8% done in 1156.4s, 2479.9s to go
# on time step 8829 (time=88.29), 0.164461 s/step
# Meep progress: 69.81000045776368/218.72999954223633 = 31.9% done in 1160.4s, 2475.4s to go
# on time step 8854 (time=88.54), 0.160992 s/step
# Meep progress: 70.06000045776368/218.72999954223633 = 32.0% done in 1164.4s, 2471.0s to go
# on time step 8879 (time=88.79), 0.161153 s/step
# Meep progress: 70.31000045776368/218.72999954223633 = 32.1% done in 1168.5s, 2466.7s to go
# on time step 8904 (time=89.04), 0.162683 s/step
# Meep progress: 70.56000045776368/218.72999954223633 = 32.3% done in 1172.5s, 2462.2s to go
# on time step 8929 (time=89.29), 0.161169 s/step
# Meep progress: 70.81000045776368/218.72999954223633 = 32.4% done in 1176.6s, 2457.8s to go
# on time step 8954 (time=89.54), 0.160826 s/step
# Meep progress: 71.06000045776368/218.72999954223633 = 32.5% done in 1180.6s, 2453.4s to go
# on time step 8979 (time=89.79), 0.160847 s/step
# Meep progress: 71.31000045776368/218.72999954223633 = 32.6% done in 1184.6s, 2449.0s to go
# on time step 9004 (time=90.04), 0.162288 s/step
# Meep progress: 71.56000045776368/218.72999954223633 = 32.7% done in 1188.7s, 2444.6s to go
# on time step 9029 (time=90.29), 0.161064 s/step
# Meep progress: 71.81000045776368/218.72999954223633 = 32.8% done in 1192.7s, 2440.2s to go
# on time step 9054 (time=90.54), 0.161255 s/step
# Meep progress: 72.06000045776368/218.72999954223633 = 32.9% done in 1196.7s, 2435.8s to go
# on time step 9079 (time=90.79), 0.161662 s/step
# Meep progress: 72.31000045776368/218.72999954223633 = 33.1% done in 1200.8s, 2431.6s to go
# on time step 9104 (time=91.04), 0.163939 s/step
# Meep progress: 72.56000045776368/218.72999954223633 = 33.2% done in 1204.9s, 2427.2s to go
# on time step 9129 (time=91.29), 0.162077 s/step
# Meep progress: 72.81000045776368/218.72999954223633 = 33.3% done in 1208.9s, 2422.9s to go
# on time step 9154 (time=91.54), 0.161588 s/step
# Meep progress: 73.06000045776368/218.72999954223633 = 33.4% done in 1213.0s, 2418.5s to go
# on time step 9179 (time=91.79), 0.162744 s/step
# Meep progress: 73.31000045776368/218.72999954223633 = 33.5% done in 1217.0s, 2414.2s to go
# on time step 9204 (time=92.04), 0.161556 s/step
# Meep progress: 73.56000045776368/218.72999954223633 = 33.6% done in 1221.1s, 2409.9s to go
# on time step 9229 (time=92.29), 0.163629 s/step
# Meep progress: 73.81000045776368/218.72999954223633 = 33.7% done in 1225.2s, 2405.5s to go
# on time step 9254 (time=92.54), 0.161766 s/step
# Meep progress: 74.06000045776368/218.72999954223633 = 33.9% done in 1229.2s, 2401.2s to go
# on time step 9279 (time=92.79), 0.162367 s/step
# Meep progress: 74.31000045776368/218.72999954223633 = 34.0% done in 1233.3s, 2396.9s to go
# on time step 9304 (time=93.04), 0.161713 s/step
# Meep progress: 74.56000045776368/218.72999954223633 = 34.1% done in 1237.3s, 2392.5s to go
# on time step 9329 (time=93.29), 0.162358 s/step
# Meep progress: 74.81000045776368/218.72999954223633 = 34.2% done in 1241.4s, 2388.2s to go
# on time step 9354 (time=93.54), 0.16266 s/step
# Meep progress: 75.06000045776368/218.72999954223633 = 34.3% done in 1245.4s, 2383.9s to go
# on time step 9379 (time=93.79), 0.16105 s/step
# Meep progress: 75.31000045776368/218.72999954223633 = 34.4% done in 1249.5s, 2379.5s to go
# on time step 9404 (time=94.04), 0.161679 s/step
# Meep progress: 75.56000045776368/218.72999954223633 = 34.5% done in 1253.6s, 2375.2s to go
# on time step 9429 (time=94.29), 0.162995 s/step
# Meep progress: 75.81000045776368/218.72999954223633 = 34.7% done in 1257.6s, 2370.8s to go
# on time step 9454 (time=94.54), 0.161032 s/step
# Meep progress: 76.06000045776368/218.72999954223633 = 34.8% done in 1261.7s, 2366.6s to go
# on time step 9479 (time=94.79), 0.163527 s/step
# Meep progress: 76.31000045776368/218.72999954223633 = 34.9% done in 1265.7s, 2362.3s to go
# on time step 9504 (time=95.04), 0.162502 s/step
# Meep progress: 76.56000045776368/218.72999954223633 = 35.0% done in 1269.8s, 2358.1s to go
# on time step 9529 (time=95.29), 0.164335 s/step
# Meep progress: 76.81000045776368/218.72999954223633 = 35.1% done in 1273.9s, 2353.8s to go
# on time step 9554 (time=95.54), 0.162597 s/step
# Meep progress: 77.06000045776368/218.72999954223633 = 35.2% done in 1277.9s, 2349.4s to go
# on time step 9579 (time=95.79), 0.160565 s/step
# Meep progress: 77.31000045776368/218.72999954223633 = 35.3% done in 1282.0s, 2345.1s to go
# on time step 9604 (time=96.04), 0.162182 s/step
# Meep progress: 77.56000045776368/218.72999954223633 = 35.5% done in 1286.0s, 2340.7s to go
# on time step 9629 (time=96.29), 0.161248 s/step
# Meep progress: 77.81000045776368/218.72999954223633 = 35.6% done in 1290.1s, 2336.4s to go
# on time step 9654 (time=96.54), 0.16205 s/step
# Meep progress: 78.06000045776368/218.72999954223633 = 35.7% done in 1294.1s, 2332.0s to go
# on time step 9679 (time=96.79), 0.160699 s/step
# Meep progress: 78.31000045776368/218.72999954223633 = 35.8% done in 1298.1s, 2327.7s to go
# on time step 9704 (time=97.04), 0.161021 s/step
# Meep progress: 78.56000045776368/218.72999954223633 = 35.9% done in 1302.2s, 2323.4s to go
# on time step 9729 (time=97.29), 0.162275 s/step
# Meep progress: 78.81000045776368/218.72999954223633 = 36.0% done in 1306.2s, 2319.0s to go
# on time step 9754 (time=97.54), 0.16115 s/step
# Meep progress: 79.06000045776368/218.72999954223633 = 36.1% done in 1310.3s, 2314.8s to go
# on time step 9779 (time=97.79), 0.163001 s/step
# Meep progress: 79.31000045776368/218.72999954223633 = 36.3% done in 1314.3s, 2310.5s to go
# on time step 9804 (time=98.04), 0.161911 s/step
# Meep progress: 79.56000045776368/218.72999954223633 = 36.4% done in 1318.3s, 2306.1s to go
# on time step 9829 (time=98.29), 0.160629 s/step
# Meep progress: 79.81000045776368/218.72999954223633 = 36.5% done in 1322.4s, 2301.8s to go
# on time step 9854 (time=98.54), 0.161299 s/step
# Meep progress: 80.06000045776368/218.72999954223633 = 36.6% done in 1326.4s, 2297.5s to go
# on time step 9879 (time=98.79), 0.162081 s/step
# Meep progress: 80.31000045776368/218.72999954223633 = 36.7% done in 1330.4s, 2293.1s to go
# on time step 9904 (time=99.04), 0.16105 s/step
# Meep progress: 80.56000045776368/218.72999954223633 = 36.8% done in 1334.5s, 2288.8s to go
# on time step 9929 (time=99.29), 0.160728 s/step
# Meep progress: 80.81000045776368/218.72999954223633 = 36.9% done in 1338.5s, 2284.5s to go
# on time step 9954 (time=99.54), 0.162826 s/step
# Meep progress: 81.06000045776368/218.72999954223633 = 37.1% done in 1342.6s, 2280.2s to go
# on time step 9979 (time=99.79), 0.162671 s/step
# Meep progress: 81.31000045776368/218.72999954223633 = 37.2% done in 1346.7s, 2276.0s to go
# on time step 10004 (time=100.04), 0.162817 s/step
# Meep progress: 81.56000045776368/218.72999954223633 = 37.3% done in 1350.8s, 2271.8s to go
# on time step 10029 (time=100.29), 0.164414 s/step
# Meep progress: 81.81000045776368/218.72999954223633 = 37.4% done in 1354.9s, 2267.6s to go
# on time step 10054 (time=100.54), 0.163571 s/step
# Meep progress: 82.06000045776368/218.72999954223633 = 37.5% done in 1358.9s, 2263.3s to go
# on time step 10079 (time=100.79), 0.162567 s/step
# Meep progress: 82.31000045776368/218.72999954223633 = 37.6% done in 1363.0s, 2259.0s to go
# on time step 10104 (time=101.04), 0.161073 s/step
# Meep progress: 82.56000045776368/218.72999954223633 = 37.7% done in 1367.0s, 2254.6s to go
# on time step 10129 (time=101.29), 0.161248 s/step
# Meep progress: 82.81000045776368/218.72999954223633 = 37.9% done in 1371.0s, 2250.4s to go
# on time step 10154 (time=101.54), 0.162142 s/step
# Meep progress: 83.06000045776368/218.72999954223633 = 38.0% done in 1375.1s, 2246.1s to go
# on time step 10179 (time=101.79), 0.16168 s/step
# Meep progress: 83.31000045776368/218.72999954223633 = 38.1% done in 1379.1s, 2241.8s to go
# on time step 10204 (time=102.04), 0.161837 s/step
# Meep progress: 83.56000045776368/218.72999954223633 = 38.2% done in 1383.2s, 2237.5s to go
# on time step 10229 (time=102.29), 0.161925 s/step
# Meep progress: 83.81000045776368/218.72999954223633 = 38.3% done in 1387.3s, 2233.2s to go
# on time step 10254 (time=102.54), 0.162487 s/step
# Meep progress: 84.06000045776368/218.72999954223633 = 38.4% done in 1391.3s, 2229.0s to go
# on time step 10279 (time=102.79), 0.162816 s/step
# Meep progress: 84.31000045776368/218.72999954223633 = 38.5% done in 1395.3s, 2224.7s to go
# on time step 10304 (time=103.04), 0.161128 s/step
# Meep progress: 84.56000045776368/218.72999954223633 = 38.7% done in 1399.4s, 2220.4s to go
# on time step 10329 (time=103.29), 0.16082 s/step
# Meep progress: 84.81000045776368/218.72999954223633 = 38.8% done in 1403.4s, 2216.0s to go
# on time step 10354 (time=103.54), 0.160512 s/step
# Meep progress: 85.07000045776367/218.72999954223633 = 38.9% done in 1407.5s, 2211.5s to go
# on time step 10380 (time=103.8), 0.159392 s/step
# ...
# on time step 19034 (time=190.34), 0.161562 s/step
# Meep progress: 171.86000045776368/218.72999954223633 = 78.6% done in 2809.9s, 766.3s to go
# on time step 19060 (time=190.6), 0.159955 s/step
# Meep progress: 172.11000045776368/218.72999954223633 = 78.7% done in 2813.9s, 762.2s to go
# on time step 19085 (time=190.85), 0.161826 s/step
# Meep progress: 172.36000045776368/218.72999954223633 = 78.8% done in 2817.9s, 758.1s to go
# on time step 19110 (time=191.1), 0.161267 s/step
# Meep progress: 172.61000045776368/218.72999954223633 = 78.9% done in 2821.9s, 754.0s to go
# on time step 19135 (time=191.35), 0.16036 s/step
# Meep progress: 172.86000045776368/218.72999954223633 = 79.0% done in 2826.0s, 749.9s to go
# on time step 19160 (time=191.6), 0.160936 s/step
# Meep progress: 173.11000045776368/218.72999954223633 = 79.1% done in 2830.0s, 745.8s to go
# on time step 19185 (time=191.85), 0.160181 s/step
# Meep progress: 173.36000045776368/218.72999954223633 = 79.3% done in 2834.0s, 741.7s to go
# on time step 19210 (time=192.1), 0.161581 s/step
# Meep progress: 173.61000045776368/218.72999954223633 = 79.4% done in 2838.1s, 737.6s to go
# on time step 19235 (time=192.35), 0.162524 s/step
# Meep progress: 173.86000045776368/218.72999954223633 = 79.5% done in 2842.2s, 733.5s to go
# on time step 19260 (time=192.6), 0.16346 s/step
# Meep progress: 174.11000045776368/218.72999954223633 = 79.6% done in 2846.2s, 729.4s to go
# on time step 19285 (time=192.85), 0.161544 s/step
# Meep progress: 174.36000045776368/218.72999954223633 = 79.7% done in 2850.2s, 725.3s to go
# on time step 19310 (time=193.1), 0.161206 s/step
# Meep progress: 174.61000045776368/218.72999954223633 = 79.8% done in 2854.2s, 721.2s to go
# on time step 19335 (time=193.35), 0.160113 s/step
# Meep progress: 174.86000045776368/218.72999954223633 = 79.9% done in 2858.3s, 717.1s to go
# on time step 19360 (time=193.6), 0.163206 s/step
# Meep progress: 175.11000045776368/218.72999954223633 = 80.1% done in 2862.3s, 713.0s to go
# on time step 19385 (time=193.85), 0.160803 s/step
# Meep progress: 175.36000045776368/218.72999954223633 = 80.2% done in 2866.4s, 708.9s to go
# on time step 19410 (time=194.1), 0.162509 s/step
# Meep progress: 175.61000045776368/218.72999954223633 = 80.3% done in 2870.4s, 704.8s to go
# on time step 19435 (time=194.35), 0.160123 s/step
# Meep progress: 175.86000045776368/218.72999954223633 = 80.4% done in 2874.4s, 700.7s to go
# on time step 19460 (time=194.6), 0.161344 s/step
# Meep progress: 176.11000045776368/218.72999954223633 = 80.5% done in 2878.5s, 696.6s to go
# on time step 19485 (time=194.85), 0.161006 s/step
# Meep progress: 176.36000045776368/218.72999954223633 = 80.6% done in 2882.5s, 692.5s to go
# on time step 19510 (time=195.1), 0.161337 s/step
# Meep progress: 176.61000045776368/218.72999954223633 = 80.7% done in 2886.5s, 688.4s to go
# on time step 19535 (time=195.35), 0.161377 s/step
# Meep progress: 176.86000045776368/218.72999954223633 = 80.9% done in 2890.6s, 684.3s to go
# on time step 19560 (time=195.6), 0.160945 s/step
# Meep progress: 177.11000045776368/218.72999954223633 = 81.0% done in 2894.6s, 680.2s to go
# on time step 19585 (time=195.85), 0.161425 s/step
# Meep progress: 177.36000045776368/218.72999954223633 = 81.1% done in 2898.6s, 676.1s to go
# on time step 19610 (time=196.1), 0.162192 s/step
# Meep progress: 177.61000045776368/218.72999954223633 = 81.2% done in 2902.7s, 672.0s to go
# on time step 19635 (time=196.35), 0.163164 s/step
# Meep progress: 177.86000045776368/218.72999954223633 = 81.3% done in 2906.7s, 667.9s to go
# on time step 19661 (time=196.61), 0.159936 s/step
# Meep progress: 178.11000045776368/218.72999954223633 = 81.4% done in 2910.7s, 663.8s to go
# on time step 19686 (time=196.86), 0.160692 s/step
# Meep progress: 178.36000045776368/218.72999954223633 = 81.5% done in 2914.8s, 659.7s to go
# on time step 19711 (time=197.11), 0.161175 s/step
# Meep progress: 178.62000045776367/218.72999954223633 = 81.7% done in 2918.9s, 655.5s to go
# on time step 19737 (time=197.37), 0.160015 s/step
# Meep progress: 178.87000045776367/218.72999954223633 = 81.8% done in 2923.0s, 651.4s to go
# on time step 19762 (time=197.62), 0.161837 s/step
# Meep progress: 179.12000045776367/218.72999954223633 = 81.9% done in 2927.1s, 647.3s to go
# on time step 19787 (time=197.87), 0.163056 s/step
# Meep progress: 179.37000045776367/218.72999954223633 = 82.0% done in 2931.1s, 643.2s to go
# on time step 19812 (time=198.12), 0.163205 s/step
# Meep progress: 179.62000045776367/218.72999954223633 = 82.1% done in 2935.2s, 639.1s to go
# on time step 19837 (time=198.37), 0.161676 s/step
# Meep progress: 179.87000045776367/218.72999954223633 = 82.2% done in 2939.2s, 635.0s to go
# on time step 19862 (time=198.62), 0.161171 s/step
# Meep progress: 180.12000045776367/218.72999954223633 = 82.3% done in 2943.3s, 630.9s to go
# on time step 19887 (time=198.87), 0.162569 s/step
# Meep progress: 180.37000045776367/218.72999954223633 = 82.5% done in 2947.3s, 626.8s to go
# on time step 19912 (time=199.12), 0.160672 s/step
# Meep progress: 180.63000045776369/218.72999954223633 = 82.6% done in 2951.4s, 622.5s to go
# on time step 19938 (time=199.38), 0.159129 s/step
# Meep progress: 180.88000045776369/218.72999954223633 = 82.7% done in 2955.4s, 618.4s to go
# on time step 19963 (time=199.63), 0.161024 s/step
# Meep progress: 181.13000045776369/218.72999954223633 = 82.8% done in 2959.5s, 614.4s to go
# on time step 19988 (time=199.88), 0.163 s/step
# Meep progress: 181.38000045776369/218.72999954223633 = 82.9% done in 2963.6s, 610.3s to go
# on time step 20013 (time=200.13), 0.161302 s/step
# Meep progress: 181.63000045776369/218.72999954223633 = 83.0% done in 2967.6s, 606.2s to go
# on time step 20038 (time=200.38), 0.161227 s/step
# Meep progress: 181.88000045776369/218.72999954223633 = 83.2% done in 2971.6s, 602.1s to go
# on time step 20063 (time=200.63), 0.161287 s/step
# Meep progress: 182.13000045776369/218.72999954223633 = 83.3% done in 2975.6s, 598.0s to go
# on time step 20088 (time=200.88), 0.160506 s/step
# Meep progress: 182.38000045776369/218.72999954223633 = 83.4% done in 2979.7s, 593.9s to go
# on time step 20113 (time=201.13), 0.160942 s/step
# Meep progress: 182.63000045776369/218.72999954223633 = 83.5% done in 2983.7s, 589.8s to go
# on time step 20138 (time=201.38), 0.162793 s/step
# Meep progress: 182.89000045776368/218.72999954223633 = 83.6% done in 2987.9s, 585.5s to go
# on time step 20163 (time=201.63), 0.160014 s/step
# Meep progress: 183.14000045776368/218.72999954223633 = 83.7% done in 2991.9s, 581.4s to go
# on time step 20188 (time=201.88), 0.161413 s/step
# Meep progress: 183.39000045776368/218.72999954223633 = 83.8% done in 2996.0s, 577.3s to go
# on time step 20213 (time=202.13), 0.163756 s/step
# Meep progress: 183.64000045776368/218.72999954223633 = 84.0% done in 3000.1s, 573.3s to go
# on time step 20238 (time=202.38), 0.162064 s/step
# Meep progress: 183.89000045776368/218.72999954223633 = 84.1% done in 3004.1s, 569.2s to go
# on time step 20263 (time=202.63), 0.16258 s/step
# Meep progress: 184.15000045776367/218.72999954223633 = 84.2% done in 3008.3s, 564.9s to go
# on time step 20289 (time=202.89), 0.15992 s/step
# Meep progress: 184.4100004577637/218.72999954223633 = 84.3% done in 3012.5s, 560.6s to go
# on time step 20315 (time=203.15), 0.159778 s/step
# Meep progress: 184.67000045776368/218.72999954223633 = 84.4% done in 3016.6s, 556.4s to go
# on time step 20341 (time=203.41), 0.15915 s/step
# Meep progress: 184.92000045776368/218.72999954223633 = 84.5% done in 3020.7s, 552.3s to go
# on time step 20366 (time=203.66), 0.162492 s/step
# Meep progress: 185.17000045776368/218.72999954223633 = 84.7% done in 3024.7s, 548.2s to go
# on time step 20391 (time=203.91), 0.161934 s/step
# Meep progress: 185.43000045776367/218.72999954223633 = 84.8% done in 3028.9s, 543.9s to go
# on time step 20417 (time=204.17), 0.159362 s/step
# Meep progress: 185.68000045776367/218.72999954223633 = 84.9% done in 3032.9s, 539.8s to go
# on time step 20442 (time=204.42), 0.16183 s/step
# Meep progress: 185.9400004577637/218.72999954223633 = 85.0% done in 3037.1s, 535.6s to go
# on time step 20468 (time=204.68), 0.159897 s/step
# Meep progress: 186.1900004577637/218.72999954223633 = 85.1% done in 3041.1s, 531.5s to go
# on time step 20493 (time=204.93), 0.161472 s/step
# Meep progress: 186.4400004577637/218.72999954223633 = 85.2% done in 3045.1s, 527.4s to go
# on time step 20518 (time=205.18), 0.160927 s/step
# Meep progress: 186.70000045776368/218.72999954223633 = 85.4% done in 3049.3s, 523.1s to go
# on time step 20544 (time=205.44), 0.159581 s/step
# Meep progress: 186.96000045776367/218.72999954223633 = 85.5% done in 3053.4s, 518.9s to go
# on time step 20570 (time=205.7), 0.159879 s/step
# Meep progress: 187.2200004577637/218.72999954223633 = 85.6% done in 3057.6s, 514.6s to go
# on time step 20596 (time=205.96), 0.159644 s/step
# Meep progress: 187.4700004577637/218.72999954223633 = 85.7% done in 3061.6s, 510.5s to go
# on time step 20621 (time=206.21), 0.163116 s/step
# Meep progress: 187.7200004577637/218.72999954223633 = 85.8% done in 3065.7s, 506.4s to go
# on time step 20646 (time=206.46), 0.162171 s/step
# Meep progress: 187.9700004577637/218.72999954223633 = 85.9% done in 3069.7s, 502.3s to go
# on time step 20671 (time=206.71), 0.161683 s/step
# Meep progress: 188.2200004577637/218.72999954223633 = 86.1% done in 3073.8s, 498.2s to go
# on time step 20696 (time=206.96), 0.160216 s/step
# Meep progress: 188.4700004577637/218.72999954223633 = 86.2% done in 3077.8s, 494.2s to go
# on time step 20721 (time=207.21), 0.160364 s/step
# Meep progress: 188.7200004577637/218.72999954223633 = 86.3% done in 3081.8s, 490.1s to go
# on time step 20746 (time=207.46), 0.16055 s/step
# Meep progress: 188.9700004577637/218.72999954223633 = 86.4% done in 3085.8s, 486.0s to go
# on time step 20771 (time=207.71), 0.160718 s/step
# Meep progress: 189.2200004577637/218.72999954223633 = 86.5% done in 3089.8s, 481.9s to go
# on time step 20796 (time=207.96), 0.160883 s/step
# Meep progress: 189.4700004577637/218.72999954223633 = 86.6% done in 3093.8s, 477.8s to go
# on time step 20821 (time=208.21), 0.160563 s/step
# Meep progress: 189.73000045776368/218.72999954223633 = 86.7% done in 3098.0s, 473.5s to go
# on time step 20847 (time=208.47), 0.159646 s/step
# Meep progress: 189.98000045776368/218.72999954223633 = 86.9% done in 3102.0s, 469.4s to go
# on time step 20872 (time=208.72), 0.161455 s/step
# Meep progress: 190.23000045776368/218.72999954223633 = 87.0% done in 3106.0s, 465.3s to go
# on time step 20897 (time=208.97), 0.160033 s/step
# Meep progress: 190.48000045776368/218.72999954223633 = 87.1% done in 3110.1s, 461.3s to go
# on time step 20922 (time=209.22), 0.162122 s/step
# Meep progress: 190.73000045776368/218.72999954223633 = 87.2% done in 3114.1s, 457.2s to go
# on time step 20947 (time=209.47), 0.161983 s/step
# Meep progress: 190.9700004577637/218.72999954223633 = 87.3% done in 3118.2s, 453.3s to go
# on time step 20971 (time=209.71), 0.171906 s/step
# Meep progress: 191.21000045776367/218.72999954223633 = 87.4% done in 3122.3s, 449.4s to go
# on time step 20995 (time=209.95), 0.167028 s/step
# Meep progress: 191.46000045776367/218.72999954223633 = 87.5% done in 3126.4s, 445.3s to go
# on time step 21020 (time=210.2), 0.164627 s/step
# Meep progress: 191.71000045776367/218.72999954223633 = 87.6% done in 3130.5s, 441.2s to go
# on time step 21045 (time=210.45), 0.165154 s/step
# Meep progress: 191.96000045776367/218.72999954223633 = 87.8% done in 3134.5s, 437.1s to go
# on time step 21070 (time=210.7), 0.161426 s/step
# Meep progress: 192.20000045776368/218.72999954223633 = 87.9% done in 3138.6s, 433.2s to go
# on time step 21094 (time=210.94), 0.168444 s/step
# Meep progress: 192.45000045776368/218.72999954223633 = 88.0% done in 3142.7s, 429.2s to go
# on time step 21119 (time=211.19), 0.164652 s/step
# Meep progress: 192.70000045776368/218.72999954223633 = 88.1% done in 3146.7s, 425.1s to go
# on time step 21144 (time=211.44), 0.160371 s/step
# Meep progress: 192.95000045776368/218.72999954223633 = 88.2% done in 3150.7s, 421.0s to go
# on time step 21169 (time=211.69), 0.160262 s/step
# Meep progress: 193.20000045776368/218.72999954223633 = 88.3% done in 3154.7s, 416.9s to go
# on time step 21194 (time=211.94), 0.160465 s/step
# Meep progress: 193.45000045776368/218.72999954223633 = 88.4% done in 3158.8s, 412.8s to go
# on time step 21219 (time=212.19), 0.163647 s/step
# Meep progress: 193.6900004577637/218.72999954223633 = 88.6% done in 3162.8s, 408.9s to go
# on time step 21243 (time=212.43), 0.166998 s/step
# Meep progress: 193.93000045776367/218.72999954223633 = 88.7% done in 3166.8s, 405.0s to go
# on time step 21267 (time=212.67), 0.166873 s/step
# Meep progress: 194.17000045776368/218.72999954223633 = 88.8% done in 3170.9s, 401.1s to go
# on time step 21291 (time=212.91), 0.168725 s/step
# Meep progress: 194.4100004577637/218.72999954223633 = 88.9% done in 3174.9s, 397.2s to go
# on time step 21315 (time=213.15), 0.167154 s/step
# Meep progress: 194.6600004577637/218.72999954223633 = 89.0% done in 3179.0s, 393.1s to go
# on time step 21340 (time=213.4), 0.162261 s/step
# Meep progress: 194.9100004577637/218.72999954223633 = 89.1% done in 3183.0s, 389.0s to go
# on time step 21365 (time=213.65), 0.162251 s/step
# Meep progress: 195.1600004577637/218.72999954223633 = 89.2% done in 3187.0s, 384.9s to go
# on time step 21390 (time=213.9), 0.161458 s/step
# Meep progress: 195.4100004577637/218.72999954223633 = 89.3% done in 3191.1s, 380.8s to go
# on time step 21415 (time=214.15), 0.161738 s/step
# Meep progress: 195.6600004577637/218.72999954223633 = 89.5% done in 3195.2s, 376.7s to go
# on time step 21440 (time=214.4), 0.162483 s/step
# Meep progress: 195.9100004577637/218.72999954223633 = 89.6% done in 3199.2s, 372.6s to go
# on time step 21465 (time=214.65), 0.1605 s/step
# Meep progress: 196.1600004577637/218.72999954223633 = 89.7% done in 3203.3s, 368.6s to go
# on time step 21490 (time=214.9), 0.164423 s/step
# Meep progress: 196.4100004577637/218.72999954223633 = 89.8% done in 3207.4s, 364.5s to go
# on time step 21515 (time=215.15), 0.164207 s/step
# Meep progress: 196.6600004577637/218.72999954223633 = 89.9% done in 3211.4s, 360.4s to go
# on time step 21540 (time=215.4), 0.162408 s/step
# Meep progress: 196.9100004577637/218.72999954223633 = 90.0% done in 3215.5s, 356.3s to go
# on time step 21565 (time=215.65), 0.16078 s/step
# Meep progress: 197.1600004577637/218.72999954223633 = 90.1% done in 3219.5s, 352.2s to go
# on time step 21590 (time=215.9), 0.1623 s/step
# Meep progress: 197.4100004577637/218.72999954223633 = 90.3% done in 3223.5s, 348.1s to go
# on time step 21615 (time=216.15), 0.160433 s/step
# Meep progress: 197.6600004577637/218.72999954223633 = 90.4% done in 3227.6s, 344.1s to go
# on time step 21640 (time=216.4), 0.162584 s/step
# Meep progress: 197.9100004577637/218.72999954223633 = 90.5% done in 3231.6s, 340.0s to go
# on time step 21665 (time=216.65), 0.160634 s/step
# Meep progress: 198.1600004577637/218.72999954223633 = 90.6% done in 3235.7s, 335.9s to go
# on time step 21690 (time=216.9), 0.161668 s/step
# Meep progress: 198.4100004577637/218.72999954223633 = 90.7% done in 3239.7s, 331.8s to go
# on time step 21715 (time=217.15), 0.162851 s/step
# Meep progress: 198.6600004577637/218.72999954223633 = 90.8% done in 3243.8s, 327.7s to go
# on time step 21740 (time=217.4), 0.163083 s/step
# Meep progress: 198.9100004577637/218.72999954223633 = 90.9% done in 3247.9s, 323.6s to go
# on time step 21765 (time=217.65), 0.162201 s/step
# Meep progress: 199.1600004577637/218.72999954223633 = 91.1% done in 3251.9s, 319.5s to go
# on time step 21790 (time=217.9), 0.162533 s/step
# Meep progress: 199.4100004577637/218.72999954223633 = 91.2% done in 3256.0s, 315.5s to go
# on time step 21815 (time=218.15), 0.163178 s/step
# Meep progress: 199.6600004577637/218.72999954223633 = 91.3% done in 3260.1s, 311.4s to go
# on time step 21840 (time=218.4), 0.161713 s/step
# Meep progress: 199.9100004577637/218.72999954223633 = 91.4% done in 3264.1s, 307.3s to go
# on time step 21865 (time=218.65), 0.163332 s/step
# run 0 finished at t = 218.74 (21874 timesteps)

# %% [markdown]
# ### Results

# %%
def field_func(x):
    return np.real(x)
field_parameters={
    "alpha": 0.8,
    "cmap": "jet",
    "interpolation": "none",
    "post_process": field_func,
    "colorbar":True,
}
monitor_parameters={
    "offset":30,
    "label_alpha":0.5,
    "label_color":'blue',
}
source_parameters={
    "offset":-20,
    "label_alpha":0.5,
    "label_color":'red',
}
colorbar_parameters={
    "label":'Field - Ez',
    "orientation":'vertical',
    "extend":'neither',
    "format":None,
    "position":'right',
    "size":'5%',
    "pad":'5%',
}
fig=plt.figure(figsize=(12,4))
sim.plot2D(
    output_plane=mp.Volume(center=mp.Vector3(), size=mp.Vector3(sx,sy,0)),
    labels='Teste',
    monitor_parameters=monitor_parameters,
    source_parameters=source_parameters,
    fields=mp.Ez,
    field_parameters=field_parameters,
    colorbar_parameters=colorbar_parameters)
# Out:
# /home/adolfofh/mambaforge/lib/python3.9/site-packages/meep/visualization.py:271: UserWarning: The specified user volume is larger than the simulation domain and has been truncated.
#   warnings.warn(
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
def field_func_dB(x):
    x_dB = 10*np.log10(x*np.conjugate(x))
    x_norm = x_dB - x_dB.max()
    x_norm[np.where(x_norm < -30)] = -30
    return x_norm
field_parameters={
    "alpha": 0.8,
    "cmap": "jet",
    "interpolation": "none",
    "post_process": field_func_dB,
    "colorbar":True,
}
colorbar_parameters={
    "label":'Field - Ez',
    "orientation":'vertical',
    "extend":'neither',
    "format":None,
    "position":'right',
    "size":'5%',
    "pad":'5%',
}
fig=plt.figure(figsize=(12,4))
sim.plot2D(
    output_plane=mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(16,16,0)),
    labels='Teste',
    monitor_parameters=monitor_parameters,
    source_parameters=source_parameters,
    fields=mp.Ez,
    field_parameters=field_parameters,
    colorbar_parameters=colorbar_parameters)
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>
